# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Machine-Learning-A-Z-Codes-Datasets\Machine Learning A-Z\Part 2 - Regression\Section 6 - Polynomial Regression\Python\Position_Salaries.csv")
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
plt.figure(figsize=(2,2))
plt.plot(df['Level'],df['Salary'],'.b')

# %%
x = df.iloc[:,[1]].values
y = df.iloc[:,-1].values
pd.DataFrame({'x': x.flatten(),
             'y':y.flatten()})
# Out:
#     x        y
# 0   1    45000
# 1   2    50000
# 2   3    60000
# 3   4    80000
# 4   5   110000
# 5   6   150000
# 6   7   200000
# 7   8   300000
# 8   9   500000
# 9  10  1000000

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.plot(x,y,'.b')
plt.plot(x,lr.predict(x),'r')

# %% [markdown]
# ## Training the Polynomial Regression model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4)
ply_trans = poly.fit_transform(x)
lr2 = LinearRegression()
lr2.fit(ply_trans,y)
# Out:
# LinearRegression()

# %%
plt.plot(x,y,'.b')
plt.plot(x,lr2.predict(ply_trans),'r')

# %%
x_grid = np.arange(x.min(),x.max(),0.1)    # divide the range into small inputs and then reshape the same into len(input) rows and 1 column.
x_grid = x_grid.reshape(len(x_grid),1)

plt.plot(x,y,'.b')
plt.plot(x_grid,lr2.predict(poly.fit_transform(x_grid)),'r')

# %%
lr.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lr2.predict(poly.fit_transform([[6.5]]))
# Out:
# array([158862.4526515])

# %%
pd.DataFrame({'x': x.flatten(),
             'y':y.flatten()})
# Out:
#     x        y
# 0   1    45000
# 1   2    50000
# 2   3    60000
# 3   4    80000
# 4   5   110000
# 5   6   150000
# 6   7   200000
# 7   8   300000
# 8   9   500000
# 9  10  1000000
